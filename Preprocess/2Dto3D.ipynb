# %%
from openai import OpenAI
from Dimension_trans import run_grounding_pipeline, question_grounding_point
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 from openai import OpenAI
# ----> 2 from Dimension_trans import run_grounding_pipeline, question_grounding_point
#
# File ~/DexGarmentLab/Preprocess/Dimension_trans.py:12
#       9 import cv2
#      11 # 复用采集脚本里的环境与投影函数
# ---> 12 from Deformable_Tops_Collect import FoldTops_Env, get_rgb_index
#      15 # ==============================
#      16 # 1. 文本提示 & vLLM 调用封装
#      17 # ==============================
#      19 question_grounding_point = (
#      20     "Given an image of a potentially deformable garment, identify and localize the following key regions: "
#      21     "left_cuff, right_cuff, left_collar, right_collar, center_collar, left_hem, right_hem, center_hem, "
#    (...)
#      32     "point; left_waist: left waist point; right_waist: right waist point. Ensure all regions are included in the output."
#      33 )
#
# File ~/DexGarmentLab/Preprocess/Deformable_Tops_Collect.py:1
# ----> 1 from isaacsim import SimulationApp
#       3 # 启动 Isaac Sim 应用
#       4 # - headless=False 表示启用图形界面，便于观察仿真效果与调试
#       5 simulation_app = SimulationApp({"headless": False})
#
# ModuleNotFoundError: No module named 'isaacsim'

# %%
client = OpenAI(
    base_url="http://127.0.0.1:8000/v1",   # 按你启动 vLLM 时的地址改
    api_key="EMPTY",                      # vLLM 一般无鉴权，随便填
)
model_name_ft = "你的Qwen3-VL模型名"
